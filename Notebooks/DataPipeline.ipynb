# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewcgaitskell/celldb/blob/master/DataPipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Libraries

# %%
import pandas as pd
import numpy as np

# %%
import os
dirname = os.getcwd()
print(dirname)
# Out:
# /home/dmtools/Code/universal-ingestion/Notebooks

# %%
os.environ['MPLCONFIGDIR'] = dirname
import matplotlib

# %%
#!pip install xlsxwriter
#!pip install xlrd
#!pip install matplotlib
import xlsxwriter
import xlrd

# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Introduction

# %%
from datetime import datetime

# %%
from datetime import datetime
my_date = datetime.now()
print(my_date.isoformat())
# Out:
# 2025-07-10T08:22:18.996750

# %%
print(my_date.strftime('%Y-%m-%dT%H:%M:%S.%f%z'))
# Out:
# 2025-07-10T08:22:18.996750

# %%
runid = "R" + my_date.strftime('%Y%m%d%H%M%S%f%z')
runid
# Out:
# 'R20250710082218996750'

# %%
dirname = os.getcwd()
print(dirname)
# Out:
# /home/dmtools/Code/universal-ingestion/Notebooks

# %% [markdown]
# ## Upload File

# %% [markdown]
# # Excel Data Types

# %% [markdown]
# The following functions are use to work out the data type of an excel cell.

# %%
def validate_date(date_text):
    try:
        format_string = '%Y-%m-%d %H:%M:%S'
        datetime.strptime(date_text, format_string)
        return "OK"
    except ValueError:
        return None

def GetDataType(row_in):
    valueasstring = str(row_in['CellValue'])
    if validate_date(valueasstring) != None:
        return 'Date'
    elif valueasstring.isnumeric():
        return 'Number'
    else:
        return 'Text'

def add1_2row(row_in):
    return row_in['RowID'] + 1


def add1_2column(row_in):
    return row_in['ColumnID'] + 1

# %%
#from ipywidgets import FileUpload
#upload = FileUpload()
#upload

# %%
#import io
#filedf = pd.read_excel(upload.data[0],sheet_name=None, header=None, encoding='utf-8', errors='ignore')
#filedf = pd.read_excel(upload.data[0],sheet_name=None, header=None)
filename = dirname + '/Data.xlsx'
filedf = pd.read_excel(filename,engine='openpyxl', sheet_name=None, header=None)
#/content/drive/MyDrive/Work/Data/Data.xlsx

# %%
#filedf

# %% [markdown]
# # Read All Sheets into Data Frame

# %%
sheetnames = list(filedf.keys())

# %%
print(sheetnames)
# Out:
# ['AgeGenderSheet', 'HomeSheet', 'JobSheet', 'MaritalDepartmentSheet', 'DataMap', 'TemplateValidationMap', 'DataSet', 'Rules', 'Palette', 'PickList', 'MetaData']

# %% [markdown]
# Each Sheet is retrieved into Dataframes
#
# DataMapDF = specdf['DataMap']
# TemplateValidationMapDF = specdf['TemplateValidationMap']
# DataSetDF = specdf['DataSet']
# RulesDF = specdf['Rules']
# PaletteDF = specdf['Palette']
# PickListDF = specdf['PickList']
# datadf = pd.DataFrame()

# %% [markdown]
# The following converts the whole spreadsheet into a cell database and this is used throughout for all data frame population.

# %%
celldbstagedf = pd.DataFrame()
sheetdf = filedf['DataMap'].copy()
sheetdf["RowID"] = sheetdf.index
#sheetdf

# %%
for currentsheetname in sheetnames:

    sheetdf = filedf[currentsheetname].copy()
    sheetdf["RowID"] = sheetdf.index
    celldb = pd.melt(sheetdf, id_vars=['RowID'])
    celldb = celldb.rename(columns={"variable": "ColumnID", "value": "CellValue"})
    celldb["CellType"] = "Unset"
    celldb["FileName"] = runid
    celldb["SheetName"] = currentsheetname
    
    celldb["ColumnID"] = celldb["ColumnID"]

    try:
        celldb["CellType"] = celldb.apply(GetDataType, axis=1)
        celldb["RowID"] = celldb.apply(add1_2row, axis=1)
        celldb["ColumnID"] = celldb.apply(add1_2column, axis=1)

    except:
        celldb["CellType"] = 'unknown'
        celldb["RowID"] = 0
        celldb["ColumnID"] = 0

    # Use pd.concat instead of append
    celldbstagedf = pd.concat([celldbstagedf, celldb], ignore_index=True)

    celldb = pd.DataFrame()

# %%
fullcelldb = celldbstagedf.copy()

# %%
#df = celldbstagedf[celldbstagedf['SheetName']=='AgeGenderSheet']
parametersheets = ['DataMap', 'TemplateValidationMap', 'DataSet', 'Rules', 'Palette', 'PickList']
DatasetCells = fullcelldb[~fullcelldb.SheetName.isin(parametersheets)]
#DatasetCells

#df[~df.country.isin(countries_to_keep)]

# %% [markdown]
# # Get Picklist Values

# %% [markdown]
# Picklist are like a mini Master Data Management System
#
# They define the acceptable values for a partcular Field in Excel
#
# The challenge here was to check one column to a another column that contained a list.  I go there in the end.

# %%
PickListCells = pd.DataFrame()
# This process uses the full cell database as the column headings are the Picklist Names
PickListCells = fullcelldb[(fullcelldb['SheetName'] == 'PickList')].copy()
# PickListCellsList = PickListCells.groupby('ColumnID')['CellValue'].apply(lambda group_series: group_series.tolist()).reset_index()

PickListCellsList = PickListCells.groupby('ColumnID').agg({'CellValue':lambda x: list(x)})

# these were odd, but glad I work them out, it is important to realise that these are operations on a number of rows, not just one
# maybe it was the axis that made the difference!
PickListCellsList['KeyWord'] = PickListCellsList.apply(lambda row : row['CellValue'][0], axis = 1)
PickListCellsList['FormulaKeyWord'] = PickListCellsList.apply(lambda row : 'PickList', axis = 1)
PickListCellsList['List'] = PickListCellsList.apply(lambda row : row['CellValue'][1:], axis = 1)
# PickListCellsList['KeyWord'] = PickListCellsList['CellValue']
#PickListCellsList= pd.DataFrame(PickListCellsList, columns=['KeyWord', 'List'])
PickListCellsList = pd.DataFrame(PickListCellsList, columns=['KeyWord', 'FormulaKeyWord', 'List'])
#PickListCellsList.head()

# %%
# These were attempts at creating a suitable list for the function to check to

# PickListCellsList['Result'] = PickListCellsList['KeyWord'].isin(PickListCellsList['List']).map({True: 0, False: 1})

# PickListCellsList['Result'] = PickListCellsList['KeyWord'].str.contains('|'.join(PickListCellsList['List']))
# PickListCellsList['Result'] = PickListCellsList['KeyWord'].str.contains('|'.join(x) for x in PickListCellsList['List'])
# ["".join(x) for x in lst]
# PickListCellsList['ListAsString'] = PickListCellsList['List'].str.join('-')
# PickListCellsList['ListAsTuple'] = tuple(PickListCellsList['CellValue'])

# %%
#MyList = pd.DataFrame()
#MyList =  PickListCellsList
# still do not know why the following DOES NOT WORK!
# MyList['Result'] = PickListCellsList['ListAsString'].isin(PickListCellsList['KeyWord'])

# leaving this as a rememberance of the 6 hours spent on this!
# MyList['Result1'] = PickListCellsList['KeyWord'].apply(lambda x: any(i in x for i in PickListCellsList['List']))
# MyList['Result2'] = PickListCellsList['ListAsString'].str.contains(PickListCellsList['KeyWord'])
# mask = df['A'].apply(lambda x: any(i in x for i in search_list))
# PickListCellsList['Result2'] = PickListCellsList['ListAsTuple'].str.contains(PickListCellsList['KeyWord'])
# PickListCellsList['Result2'] = PickListCellsList['KeyWord'].str.contains(tuple(PickListCellsList['List']))
# PickListCellsList['ListAsTuple'].isin(PickListCellsList['KeyWord'])
# MyList['Result2'] = PickListCellsList['List'].apply(lambda x: True if (PickListCellsList.KeyWord in x).any() else False)
######### MyList['sing'] = 'Single'
# MyList['res1'] = MyList.apply(lambda ts: any(ts == 'Single'), axis=1)
# MyList['res2'] = MyList.apply(lambda ts: MyList['KeyWord'].str.contains('Single'), axis=1)
######### MyList['res3'] = MyList.apply(lambda x: x['sing'] in x['ListAsTuple'], axis=1)  ###############
######### MyList['res4'] = MyList.apply(lambda x: x['sing'] in x['List'], axis=1).map({True: 1, False: 0}) ###############
# # # # dataset.apply(lambda x: x['CellValue'] in x['PickList'], axis=1).map({True: 1, False: 0})
# data['Activity].str.contains('skin diving')
# lambda x : True if (x > 10 and x < 20) else False
#MyList.head()
# https://stackoverflow.com/questions/48460234/pandas-apply-valueerror-the-truth-value-of-a-series-is-ambigous

# %% [markdown]
# # Get Data Map

# %%
DataMapCells = pd.DataFrame()
DataMapCells = fullcelldb[(fullcelldb['SheetName'] == 'DataMap')].copy()
#DataMapCells.head()

# %% [markdown]
# Below extracts a Sheet from the cell database and reshapes it to it original tabular form.

# %%
DataMap = pd.DataFrame()
DataMap = DataMapCells.pivot_table(index = ['RowID'], values = 'CellValue',columns = 'ColumnID', aggfunc = 'max')
ColumnHeadings = DataMap.iloc[0]
ColumnHeadingsList = list(ColumnHeadings)
print(ColumnHeadingsList)
ColumnHeadingsListTuple = enumerate(ColumnHeadingsList,start=1)
ColumnHeadingsListDict = dict(ColumnHeadingsListTuple)
print(ColumnHeadingsListDict)
DataMap = DataMap.rename(columns=ColumnHeadingsListDict)
DataMap = DataMap.drop([1])
#DataMap.head()
# Out:
# ['SheetName', 'ReferenceText', 'RowFromReferenceText', 'ColumnFromReferenceText', 'TemplateText', 'DataGroup', 'DataCategory', 'DataScope', 'FieldID', 'Column Header', 'DataSetID']
# {1: 'SheetName', 2: 'ReferenceText', 3: 'RowFromReferenceText', 4: 'ColumnFromReferenceText', 5: 'TemplateText', 6: 'DataGroup', 7: 'DataCategory', 8: 'DataScope', 9: 'FieldID', 10: 'Column Header', 11: 'DataSetID'}

# %% [markdown]
# # Make Rules Database

# %%
RulesCells = pd.DataFrame()
RulesCells = fullcelldb[(fullcelldb['SheetName'] == 'Rules')].copy()
#RulesCells.head()

# %%
RulesMatrix = pd.DataFrame()
RulesMatrix = RulesCells.pivot_table(index = ['RowID'], values = 'CellValue',columns = 'ColumnID', aggfunc = 'max')
ColumnHeadings = RulesMatrix.iloc[0]
ColumnHeadingsList = list(ColumnHeadings)
print(ColumnHeadingsList)
ColumnHeadingsListTuple = enumerate(ColumnHeadingsList,start=1)
ColumnHeadingsListDict = dict(ColumnHeadingsListTuple)
print(ColumnHeadingsListDict)
RulesMatrix = RulesMatrix.rename(columns=ColumnHeadingsListDict)
RulesMatrix = RulesMatrix.drop([1])
RulesMatrix.head()
# Out:
# ['RuleID', 'DataSetID', 'FieldID', 'DataType', 'Format', 'RangeFrom', 'RangeTo', 'Null', 'Length', 'PickList', 'Rule1', 'Rule2', 'Rule3']
# {1: 'RuleID', 2: 'DataSetID', 3: 'FieldID', 4: 'DataType', 5: 'Format', 6: 'RangeFrom', 7: 'RangeTo', 8: 'Null', 9: 'Length', 10: 'PickList', 11: 'Rule1', 12: 'Rule2', 13: 'Rule3'}
# ColumnID RuleID DataSetID FieldID DataType Format RangeFrom RangeTo Null  \
# RowID
# 2             1      Ages    Name     Text    NaN       NaN     NaN    N
# 3             2      Ages     Age   Number    NaN       NaN     NaN    N
# 4             3   Genders    Name     Text    NaN       NaN     NaN    N
# 5             4   Genders  Gender     Text    NaN       NaN     NaN    N
# 6             5       DoB    Name     Text    NaN       NaN     NaN    N
#
# ColumnID Length PickList     Rule1           Rule2 Rule3
# RowID
# 2           NaN      NaN       NaN             NaN   NaN
# 3           NaN      NaN  Positive  GreaterThanTen   NaN
# 4           NaN      NaN       NaN             NaN   NaN
# 5           NaN   Gender       NaN             NaN   NaN
# 6           NaN      NaN       NaN             NaN   NaN

# %%
RulesMatrix.head()
# Out:
# ColumnID RuleID DataSetID FieldID DataType Format RangeFrom RangeTo Null  \
# RowID
# 2             1      Ages    Name     Text    NaN       NaN     NaN    N
# 3             2      Ages     Age   Number    NaN       NaN     NaN    N
# 4             3   Genders    Name     Text    NaN       NaN     NaN    N
# 5             4   Genders  Gender     Text    NaN       NaN     NaN    N
# 6             5       DoB    Name     Text    NaN       NaN     NaN    N
#
# ColumnID Length PickList     Rule1           Rule2 Rule3
# RowID
# 2           NaN      NaN       NaN             NaN   NaN
# 3           NaN      NaN  Positive  GreaterThanTen   NaN
# 4           NaN      NaN       NaN             NaN   NaN
# 5           NaN   Gender       NaN             NaN   NaN
# 6           NaN      NaN       NaN             NaN   NaN

# %% [markdown]
# The above is the Rules definition sheet. It used KeyWords to define the checks.  Below forms a list of KeyWords that are relevant to a particular field in a DataSet

# %%
Rules2Apply = pd.DataFrame()
Rules2Apply = pd.melt(RulesMatrix, id_vars=['RuleID', 'DataSetID', 'FieldID'])
Rules2Apply
# Out:
#     RuleID     DataSetID        FieldID  ColumnID   value
# 0        1          Ages           Name  DataType    Text
# 1        2          Ages            Age  DataType  Number
# 2        3       Genders           Name  DataType    Text
# 3        4       Genders         Gender  DataType    Text
# 4        5           DoB           Name  DataType    Text
# ..     ...           ...            ...       ...     ...
# 145     11          Jobs      Job_Title     Rule3     NaN
# 146     12          Jobs  Employee_Name     Rule3     NaN
# 147     13          Jobs             ID     Rule3     NaN
# 148     14  HomeLocation       Employee     Rule3     NaN
# 149     15  HomeLocation       Location     Rule3     NaN
#
# [150 rows x 5 columns]

# %%
Rules2Apply.value.unique()
# Out:
# array(['Text', 'Number', 'Date', nan, 'N', 'Gender', 'MaritalStatus',
#        'HomeLocation', 'Positive', 'GreaterThanTen'], dtype=object)

# %%
Rules2Apply = Rules2Apply.rename(columns={"ColumnID": "RuleType", "value": "KeyWord"})
Rules2Apply = Rules2Apply[Rules2Apply.KeyWord.notnull()]
Rules2Apply.KeyWord.unique()
# Out:
# array(['Text', 'Number', 'Date', 'N', 'Gender', 'MaritalStatus',
#        'HomeLocation', 'Positive', 'GreaterThanTen'], dtype=object)

# %%
# df['A'] = df.apply(lambda x: x['B'] if x['A']==0 else x['A'], axis=1)
# The following adds the KeyWord Null into the Rules list - if Null is N, this means Nulls are Not Allowed
Rules2Apply['KeyWord'] = Rules2Apply.apply(lambda x: x['RuleType'] if x['KeyWord']=='N' else x['KeyWord'], axis=1)
#Rules2Apply['New'] = Rules2Apply.apply(lambda x: x['RuleType'] if x['KeyWord']=='N' else x['KeyWord'], axis=1)
Rules2Apply.KeyWord.unique()
# Out:
# array(['Text', 'Number', 'Date', 'Null', 'Gender', 'MaritalStatus',
#        'HomeLocation', 'Positive', 'GreaterThanTen'], dtype=object)

# %%
PickListCellsList
# Out:
#                 KeyWord FormulaKeyWord                 List
# ColumnID
# 1         MaritalStatus       PickList    [Single, Married]
# 2          HomeLocation       PickList  [London, Liverpool]
# 3                Gender       PickList       [Male, Female]

# %%
Rules2Apply = pd.merge(Rules2Apply,PickListCellsList, on=['KeyWord'],how='left')

Rules2Apply
# Out:
#    RuleID        DataSetID        FieldID  RuleType         KeyWord  \
# 0       1             Ages           Name  DataType            Text
# 1       2             Ages            Age  DataType          Number
# 2       3          Genders           Name  DataType            Text
# 3       4          Genders         Gender  DataType            Text
# 4       5              DoB           Name  DataType            Text
# 5       6              DoB            DoB  DataType            Date
# 6       7    MaritalStatus           Name  DataType            Text
# 7       8    MaritalStatus         Status  DataType            Text
# 8       9  DepartmentTable           Name  DataType            Text
# 9      10  DepartmentTable     Department  DataType            Text
# 10     11             Jobs      Job_Title  DataType            Text
# 11     12             Jobs  Employee_Name  DataType            Text
# 12     13             Jobs             ID  DataType          Number
# 13     14     HomeLocation       Employee  DataType            Text
# 14     15     HomeLocation       Location  DataType            Text
# 15      1             Ages           Name      Null            Null
# 16      2             Ages            Age      Null            Null
# 17      3          Genders           Name      Null            Null
# 18      4          Genders         Gender      Null            Null
# 19      5              DoB           Name      Null            Null
# 20      6              DoB            DoB      Null            Null
# 21      7    MaritalStatus           Name      Null            Null
# 22      8    MaritalStatus         Status      Null            Null
# 23      9  DepartmentTable           Name      Null            Null
# 24     10  DepartmentTable     Department      Null            Null
# 25     11             Jobs      Job_Title      Null            Null
# 26     12             Jobs  Employee_Name      Null            Null
# 27     13             Jobs             ID      Null            Null
# 28     14     HomeLocation       Employee      Null            Null
# 29     15     HomeLocation       Location      Null            Null
# 30      4          Genders         Gender  PickList          Gender
# 31      8    MaritalStatus         Status  PickList   MaritalStatus
# 32     15     HomeLocation       Location  PickList    HomeLocation
# 33      2             Ages            Age     Rule1        Positive
# 34      2             Ages            Age     Rule2  GreaterThanTen
#
#    FormulaKeyWord                 List
# 0             NaN                  NaN
# 1             NaN                  NaN
# 2             NaN                  NaN
# 3             NaN                  NaN
# 4             NaN                  NaN
# 5             NaN                  NaN
# 6             NaN                  NaN
# 7             NaN                  NaN
# 8             NaN                  NaN
# 9             NaN                  NaN
# 10            NaN                  NaN
# 11            NaN                  NaN
# 12            NaN                  NaN
# 13            NaN                  NaN
# 14            NaN                  NaN
# 15            NaN                  NaN
# 16            NaN                  NaN
# 17            NaN                  NaN
# 18            NaN                  NaN
# 19            NaN                  NaN
# 20            NaN                  NaN
# 21            NaN                  NaN
# 22            NaN                  NaN
# 23            NaN                  NaN
# 24            NaN                  NaN
# 25            NaN                  NaN
# 26            NaN                  NaN
# 27            NaN                  NaN
# 28            NaN                  NaN
# 29            NaN                  NaN
# 30       PickList       [Male, Female]
# 31       PickList    [Single, Married]
# 32       PickList  [London, Liverpool]
# 33            NaN                  NaN
# 34            NaN                  NaN

# %% [markdown]
# # Add Code and Formulae to Rules Database

# %% [markdown]
# Palette defines the Rule Text and Rule Formula.

# %%
PaletteCells = pd.DataFrame()
PaletteCells = fullcelldb[(fullcelldb['SheetName'] == 'Palette')].copy()
PaletteCells.head()
# Out:
#      RowID  ColumnID CellValue CellType               FileName SheetName
# 933      1         1   KeyWord     Text  R20250710082218996750   Palette
# 934      2         1      Date     Text  R20250710082218996750   Palette
# 935      3         1    Number     Text  R20250710082218996750   Palette
# 936      4         1      Text     Text  R20250710082218996750   Palette
# 937      5         1   NotNull     Text  R20250710082218996750   Palette

# %%
Palette = pd.DataFrame()
Palette = PaletteCells.pivot_table(index = ['RowID'], values = 'CellValue',columns = 'ColumnID', aggfunc = 'max')
ColumnHeadings = Palette.iloc[0]
ColumnHeadingsList = list(ColumnHeadings)
print(ColumnHeadingsList)
ColumnHeadingsListTuple = enumerate(ColumnHeadingsList,start=1)
ColumnHeadingsListDict = dict(ColumnHeadingsListTuple)
print(ColumnHeadingsListDict)
Palette = Palette.rename(columns=ColumnHeadingsListDict)
Palette = Palette.drop([1])
Palette.head()
# Out:
# ['KeyWord', 'Rule', 'CheckPerformed', 'ErrorMessage', 'AlteryxDataType', 'AlteryxFormula', 'RemedialAction', 'SQLFormula', 'PythonFormula']
# {1: 'KeyWord', 2: 'Rule', 3: 'CheckPerformed', 4: 'ErrorMessage', 5: 'AlteryxDataType', 6: 'AlteryxFormula', 7: 'RemedialAction', 8: 'SQLFormula', 9: 'PythonFormula'}
# ColumnID     KeyWord                  Rule          CheckPerformed  \
# RowID
# 2               Date          Must Be Date       Data Type is Date
# 3             Number        Must Be Number     Data Type is Number
# 4               Text          Must Be Text       Data Type is Text
# 5            NotNull      Must Not Be Null    Field cannot be Null
# 6         1OrGreater  Must be 1 or greater  Number is 1 or greater
#
# ColumnID        ErrorMessage AlteryxDataType  \
# RowID
# 2           Date Not Entered            Date
# 3         Number Not Entered          Double
# 4           Text Not Entered        V_String
# 5           No Data in Field             NaN
# 6          Number is below 1             NaN
#
# ColumnID                                     AlteryxFormula  \
# RowID
# 2           Length([CellValue]) > 0 and [CellType] = "Date"
# 3         Length([CellValue]) > 0 and [CellType] = "Number"
# 4         Length([CellValue]) > 0 and Contains([CellType...
# 5                                   Length([CellValue]) > 0
# 6                                  ToNumber([CellValue])>=1
#
# ColumnID            RemedialAction  \
# RowID
# 2                       Enter Date
# 3                     Enter Number
# 4                    Enter as Text
# 5              Enter Required Data
# 6         Enter value 1 or greater
#
# ColumnID                                         SQLFormula  \
# RowID
# 2         case when IsNULL([CellValue],'XX') = 'XX' then...
# 3         case when IsNULL([CellValue],'XX') = 'XX' then...
# 4         case when IsNULL([CellValue],'XX') = 'XX' then...
# 5         case when IsNULL([CellValue],'XX') != 'XX' the...
# 6         case when TRY_CAST([CellValue] as INT)>=1 then...
#
# ColumnID                                      PythonFormula
# RowID
# 2             np.where(dataset['CellType'] == 'Date', 1, 0)
# 3           np.where(dataset['CellType'] == 'Number', 1, 0)
# 4             np.where(dataset['CellType'] == 'Text', 1, 0)
# 5         dataset['CellValue'].isnull().map({True: 0, Fa...
# 6                                                       NaN

# %%
DatasetCells = pd.DataFrame()
DatasetCells = fullcelldb[(fullcelldb['SheetName'] == 'DataSet')].copy()
DatasetCells
# Out:
#      RowID  ColumnID  CellValue CellType               FileName SheetName
# 565      1         1  DataSetID     Text  R20250710082218996750   DataSet
# 566      2         1       Ages     Text  R20250710082218996750   DataSet
# 567      3         1       Ages     Text  R20250710082218996750   DataSet
# 568      4         1    Genders     Text  R20250710082218996750   DataSet
# 569      5         1    Genders     Text  R20250710082218996750   DataSet
# ..     ...       ...        ...      ...                    ...       ...
# 720     12        10        NaN     Text  R20250710082218996750   DataSet
# 721     13        10        NaN     Text  R20250710082218996750   DataSet
# 722     14        10        NaN     Text  R20250710082218996750   DataSet
# 723     15        10        NaN     Text  R20250710082218996750   DataSet
# 724     16        10        NaN     Text  R20250710082218996750   DataSet
#
# [160 rows x 6 columns]

# %%
Datasets = pd.DataFrame()
Datasets = DatasetCells.pivot_table(index = ['RowID'], values = 'CellValue',columns = 'ColumnID', aggfunc = 'max')
ColumnHeadings = Datasets.iloc[0]
ColumnHeadingsList = list(ColumnHeadings)
print(ColumnHeadingsList)
ColumnHeadingsListTuple = enumerate(ColumnHeadingsList,start=1)
ColumnHeadingsListDict = dict(ColumnHeadingsListTuple)
print(ColumnHeadingsListDict)
Datasets = Datasets.rename(columns=ColumnHeadingsListDict)
Datasets = Datasets.drop([1])
Datasets.head()
# Out:
# ['DataSetID', 'SheetName', 'ReferenceTextStart', 'ReferenceTextEnd', 'RowFromReferenceText', 'ColumnFromReferenceText', 'FieldPosition', 'FieldID', 'FieldDescription', 'TableOrientation']
# {1: 'DataSetID', 2: 'SheetName', 3: 'ReferenceTextStart', 4: 'ReferenceTextEnd', 5: 'RowFromReferenceText', 6: 'ColumnFromReferenceText', 7: 'FieldPosition', 8: 'FieldID', 9: 'FieldDescription', 10: 'TableOrientation'}
# ColumnID DataSetID       SheetName ReferenceTextStart ReferenceTextEnd  \
# RowID
# 2             Ages  AgeGenderSheet          Age Table     Gender Table
# 3             Ages  AgeGenderSheet          Age Table     Gender Table
# 4          Genders  AgeGenderSheet       Gender Table        DOB Table
# 5          Genders  AgeGenderSheet       Gender Table        DOB Table
# 6              DoB  AgeGenderSheet          DOB Table              NaN
#
# ColumnID RowFromReferenceText ColumnFromReferenceText FieldPosition FieldID  \
# RowID
# 2                           2                       1             1    Name
# 3                           2                       2             2     Age
# 4                           2                       0             1    Name
# 5                           2                       1             2  Gender
# 6                           2                       0             1    Name
#
# ColumnID FieldDescription TableOrientation
# RowID
# 2                    Name             Down
# 3                     Age             Down
# 4                    Name             Down
# 5                  Gender             Down
# 6                    Name             Down

# %%
#palette = pd.merge(palette, PaletteDF, on=['KeyWord'],how='left')

# %%
Tests2Do = pd.merge(Datasets, Rules2Apply, on=['FieldID', 'DataSetID'])
Tests2Do['KeyWord'] = Tests2Do.apply(lambda x: x['FormulaKeyWord'] if x['FormulaKeyWord']=='PickList' else x['KeyWord'], axis=1)
Tests2Do.head(5)
# Out:
#   DataSetID       SheetName ReferenceTextStart ReferenceTextEnd  \
# 0      Ages  AgeGenderSheet          Age Table     Gender Table
# 1      Ages  AgeGenderSheet          Age Table     Gender Table
# 2      Ages  AgeGenderSheet          Age Table     Gender Table
# 3      Ages  AgeGenderSheet          Age Table     Gender Table
# 4      Ages  AgeGenderSheet          Age Table     Gender Table
#
#   RowFromReferenceText ColumnFromReferenceText FieldPosition FieldID  \
# 0                    2                       1             1    Name
# 1                    2                       1             1    Name
# 2                    2                       2             2     Age
# 3                    2                       2             2     Age
# 4                    2                       2             2     Age
#
#   FieldDescription TableOrientation RuleID  RuleType   KeyWord FormulaKeyWord  \
# 0             Name             Down      1  DataType      Text            NaN
# 1             Name             Down      1      Null      Null            NaN
# 2              Age             Down      2  DataType    Number            NaN
# 3              Age             Down      2      Null      Null            NaN
# 4              Age             Down      2     Rule1  Positive            NaN
#
#   List
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
Tests2DoWithFormula = pd.merge(Tests2Do, Palette, on=['KeyWord'])
Tests2DoWithFormula.head()
# Out:
#   DataSetID       SheetName ReferenceTextStart ReferenceTextEnd  \
# 0      Ages  AgeGenderSheet          Age Table     Gender Table
# 1      Ages  AgeGenderSheet          Age Table     Gender Table
# 2      Ages  AgeGenderSheet          Age Table     Gender Table
# 3      Ages  AgeGenderSheet          Age Table     Gender Table
# 4   Genders  AgeGenderSheet       Gender Table        DOB Table
#
#   RowFromReferenceText ColumnFromReferenceText FieldPosition FieldID  \
# 0                    2                       1             1    Name
# 1                    2                       2             2     Age
# 2                    2                       2             2     Age
# 3                    2                       2             2     Age
# 4                    2                       0             1    Name
#
#   FieldDescription TableOrientation  ... FormulaKeyWord List  \
# 0             Name             Down  ...            NaN  NaN
# 1              Age             Down  ...            NaN  NaN
# 2              Age             Down  ...            NaN  NaN
# 3              Age             Down  ...            NaN  NaN
# 4             Name             Down  ...            NaN  NaN
#
#                        Rule       CheckPerformed         ErrorMessage  \
# 0              Must Be Text    Data Type is Text     Text Not Entered
# 1            Must Be Number  Data Type is Number   Number Not Entered
# 2          Must Be Positive   Number is Positive  Number Not Positive
# 3  Must be greater than ten      Greater than 10  Not Greater than 10
# 4              Must Be Text    Data Type is Text     Text Not Entered
#
#   AlteryxDataType                                     AlteryxFormula  \
# 0        V_String  Length([CellValue]) > 0 and Contains([CellType...
# 1          Double  Length([CellValue]) > 0 and [CellType] = "Number"
# 2             NaN                           ToNumber([CellValue])>=0
# 3             NaN                           ToNumber([CellValue])>10
# 4        V_String  Length([CellValue]) > 0 and Contains([CellType...
#
#               RemedialAction  \
# 0              Enter as Text
# 1               Enter Number
# 2      Enter Positive Number
# 3  Enter Age Greater Than 10
# 4              Enter as Text
#
#                                           SQLFormula  \
# 0  case when IsNULL([CellValue],'XX') = 'XX' then...
# 1  case when IsNULL([CellValue],'XX') = 'XX' then...
# 2  case when TRY_CAST([CellValue] as INT)>0 then ...
# 3  case when TRY_CAST([CellValue] as INT)>10 then...
# 4  case when IsNULL([CellValue],'XX') = 'XX' then...
#
#                                        PythonFormula
# 0      np.where(dataset['CellType'] == 'Text', 1, 0)
# 1    np.where(dataset['CellType'] == 'Number', 1, 0)
# 2   np.where(dataset['CellValueAsNumber'] > 0, 1, 0)
# 3  np.where(dataset['CellValueAsNumber'] > 10, 1, 0)
# 4      np.where(dataset['CellType'] == 'Text', 1, 0)
#
# [5 rows x 23 columns]

# %% [markdown]
# # Get Start Anchor Cells

# %% [markdown]
# Start Anchors are where tables are mapped from, every dataset in the spreadsheet must be anchored to a uniquely identifiable cell in a particular sheet.

# %%
startanchors = pd.DataFrame()
startanchors = pd.DataFrame(Datasets, columns=['DataSetID', 'SheetName', 'ReferenceTextStart'])
startanchors = startanchors.rename(columns={"ReferenceTextStart": "CellValue"})
startanchors = startanchors.drop_duplicates()
startanchors.head()
# Out:
#            DataSetID               SheetName             CellValue
# RowID
# 2               Ages          AgeGenderSheet             Age Table
# 4            Genders          AgeGenderSheet          Gender Table
# 6                DoB          AgeGenderSheet             DOB Table
# 8      MaritalStatus  MaritalDepartmentSheet  Marital Status Table
# 10        Department  MaritalDepartmentSheet      Department Table

# %% [markdown]
# # Get All End Anchor Cells

# %% [markdown]
# End anchors are where a dataset finishes. Probably at the next Start Anchor.
# This does mean that blank rows are validated and one needs to filter these out later.

# %%
endanchors = pd.DataFrame()
endanchors = pd.DataFrame(Datasets, columns=['DataSetID', 'SheetName', 'ReferenceTextEnd'])
endanchors = endanchors.rename(columns={"ReferenceTextEnd": "CellValue"})
endanchors = endanchors.drop_duplicates()
endanchors.head()
# Out:
#            DataSetID               SheetName     CellValue
# RowID
# 2               Ages          AgeGenderSheet  Gender Table
# 4            Genders          AgeGenderSheet     DOB Table
# 6                DoB          AgeGenderSheet           NaN
# 8      MaritalStatus  MaritalDepartmentSheet           NaN
# 10        Department  MaritalDepartmentSheet           NaN

# %% [markdown]
# # Find Start Anchors

# %% [markdown]
# Now we look for the start and finish anchor cells for each dataset.

# %%
findstartanchors = pd.DataFrame()
findstartanchors = pd.merge(startanchors, fullcelldb, on=['SheetName', 'CellValue'])
findstartanchors = findstartanchors.rename(columns={"RowID": "AnchorRow", "ColumnID": "AnchorColumn"})
findstartanchors = pd.DataFrame(findstartanchors, columns=['DataSetID', 'SheetName', 'AnchorRow', 'AnchorColumn'])
findstartanchors.head()
# Out:
#        DataSetID               SheetName  AnchorRow  AnchorColumn
# 0           Ages          AgeGenderSheet          5             2
# 1        Genders          AgeGenderSheet         14             4
# 2            DoB          AgeGenderSheet         23             1
# 3  MaritalStatus  MaritalDepartmentSheet          3             1
# 4     Department  MaritalDepartmentSheet          2             5

# %% [markdown]
# # Find End Anchors

# %% [markdown]
# Some datasets have no finish anchors as they are the last table in the sheet.

# %%
findendanchors = pd.DataFrame()
findendanchors = pd.merge(endanchors, fullcelldb, on=['SheetName', 'CellValue'])
findendanchors = findendanchors.rename(columns={"RowID": "EndRow"})
findendanchors = findendanchors[findendanchors.CellValue.notnull()]
findendanchors = pd.DataFrame(findendanchors, columns=['DataSetID', 'SheetName', 'EndRow'])
findendanchors.head()
# Out:
#   DataSetID       SheetName  EndRow
# 0      Ages  AgeGenderSheet      14
# 1   Genders  AgeGenderSheet      23

# %% [markdown]
# # Join Anchors Together

# %% [markdown]
# Join the anchors to allow them to be joined with the data table
# As stated above, some DataSets have NaN as the EndRow as there is no further data in the sheet

# %%
anchors = pd.DataFrame()
anchors = pd.merge(findstartanchors, findendanchors, on=['DataSetID', 'SheetName'], how='left')
anchors.head()
# Out:
#        DataSetID               SheetName  AnchorRow  AnchorColumn  EndRow
# 0           Ages          AgeGenderSheet          5             2    14.0
# 1        Genders          AgeGenderSheet         14             4    23.0
# 2            DoB          AgeGenderSheet         23             1     NaN
# 3  MaritalStatus  MaritalDepartmentSheet          3             1     NaN
# 4     Department  MaritalDepartmentSheet          2             5     NaN

# %% [markdown]
# # Using Anchors and Dataset Create Map to Find Data

# %% [markdown]
# The DataSet defines where the DataSets can be found from the Start Anchor Cells
# The following joins the found cells with the DataSet map.

# %%
datasetmap = pd.DataFrame()
datasetmap = pd.merge(Datasets, anchors, on=['DataSetID', 'SheetName'], how='left')
datasetmap = pd.DataFrame(datasetmap,
                          columns=['DataSetID', 'SheetName', 'FieldID',
                                   'AnchorRow', 'AnchorColumn','EndRow',
                                   'RowFromReferenceText',
                                   'ColumnFromReferenceText','FieldPosition'])

# %% [markdown]
# ## Show Dataset Map

# %%
datasetmap.head()
# Out:
#   DataSetID       SheetName FieldID  AnchorRow  AnchorColumn  EndRow  \
# 0      Ages  AgeGenderSheet    Name          5             2    14.0
# 1      Ages  AgeGenderSheet     Age          5             2    14.0
# 2   Genders  AgeGenderSheet    Name         14             4    23.0
# 3   Genders  AgeGenderSheet  Gender         14             4    23.0
# 4       DoB  AgeGenderSheet    Name         23             1     NaN
#
#   RowFromReferenceText ColumnFromReferenceText FieldPosition
# 0                    2                       1             1
# 1                    2                       2             2
# 2                    2                       0             1
# 3                    2                       1             2
# 4                    2                       0             1

# %% [markdown]
# # Find where Data Starts and what Columns Fields are In

# %% [markdown]
# One needs to now calculate the actual rows and columns of where the DataSet is.
# The above table is relative to the Anchor Cells

# %%
datasetmap['StartRow'] = datasetmap['AnchorRow'] + datasetmap['RowFromReferenceText']
datasetmap['FieldColumn'] = datasetmap['AnchorColumn'] + datasetmap['ColumnFromReferenceText']
dataset = pd.DataFrame()
dataset = pd.merge(fullcelldb, datasetmap, on=['SheetName'], how='left')
## the above may seem a cartesian join and may need to be looked at if this slows the process down
dataset
# Out:
#       RowID  ColumnID      CellValue CellType               FileName  \
# 0         1         1            NaN     Text  R20250710082218996750
# 1         1         1            NaN     Text  R20250710082218996750
# 2         1         1            NaN     Text  R20250710082218996750
# 3         1         1            NaN     Text  R20250710082218996750
# 4         1         1            NaN     Text  R20250710082218996750
# ...     ...       ...            ...      ...                    ...
# 2092      4         4            DoB     Text  R20250710082218996750
# 2093      5         4  MaritalStatus     Text  R20250710082218996750
# 2094      6         4     Department     Text  R20250710082218996750
# 2095      7         4           Jobs     Text  R20250710082218996750
# 2096      8         4   HomeLocation     Text  R20250710082218996750
#
#            SheetName DataSetID FieldID  AnchorRow  AnchorColumn  EndRow  \
# 0     AgeGenderSheet      Ages    Name        5.0           2.0    14.0
# 1     AgeGenderSheet      Ages     Age        5.0           2.0    14.0
# 2     AgeGenderSheet   Genders    Name       14.0           4.0    23.0
# 3     AgeGenderSheet   Genders  Gender       14.0           4.0    23.0
# 4     AgeGenderSheet       DoB    Name       23.0           1.0     NaN
# ...              ...       ...     ...        ...           ...     ...
# 2092        MetaData       NaN     NaN        NaN           NaN     NaN
# 2093        MetaData       NaN     NaN        NaN           NaN     NaN
# 2094        MetaData       NaN     NaN        NaN           NaN     NaN
# 2095        MetaData       NaN     NaN        NaN           NaN     NaN
# 2096        MetaData       NaN     NaN        NaN           NaN     NaN
#
#      RowFromReferenceText ColumnFromReferenceText FieldPosition StartRow  \
# 0                       2                       1             1        7
# 1                       2                       2             2        7
# 2                       2                       0             1       16
# 3                       2                       1             2       16
# 4                       2                       0             1       25
# ...                   ...                     ...           ...      ...
# 2092                  NaN                     NaN           NaN      NaN
# 2093                  NaN                     NaN           NaN      NaN
# 2094                  NaN                     NaN           NaN      NaN
# 2095                  NaN                     NaN           NaN      NaN
# 2096                  NaN                     NaN           NaN      NaN
#
#      FieldColumn
# 0              3
# 1              4
# 2              4
# 3              5
# 4              1
# ...          ...
# 2092         NaN
# 2093         NaN
# 2094         NaN
# 2095         NaN
# 2096         NaN
#
# [2097 rows x 16 columns]

# %% [markdown]
# # Filter Out Data after End Anchor Row

# %%
# Drop rows with NaN in RowID or StartRow before comparison
dataset = dataset.dropna(subset=["RowID", "StartRow"])
dataset = dataset[
    (dataset["RowID"] >= dataset["StartRow"]) &
    (dataset["ColumnID"] == dataset["FieldColumn"]) &
    (
        (dataset["RowID"] < dataset["EndRow"]) |
        pd.isnull(dataset["EndRow"])
    )
]

# %%
dataset
# Out:
#       RowID  ColumnID            CellValue CellType               FileName  \
# 148      25         1                 Paul     Text  R20250710082218996750
# 154      26         1                Ringo     Text  R20250710082218996750
# 160      27         1                Brian     Text  R20250710082218996750
# 311      25         2  1955-07-01 00:00:00     Date  R20250710082218996750
# 317      26         2  1996-01-09 00:00:00     Date  R20250710082218996750
# ...     ...       ...                  ...      ...                    ...
# 1146      7         5                  NaN     Text  R20250710082218996750
# 1163      4         6           Production     Text  R20250710082218996750
# 1167      5         6                   IT     Text  R20250710082218996750
# 1171      6         6             Accounts     Text  R20250710082218996750
# 1175      7         6                  NaN     Text  R20250710082218996750
#
#                    SheetName   DataSetID     FieldID  AnchorRow  AnchorColumn  \
# 148           AgeGenderSheet         DoB        Name       23.0           1.0
# 154           AgeGenderSheet         DoB        Name       23.0           1.0
# 160           AgeGenderSheet         DoB        Name       23.0           1.0
# 311           AgeGenderSheet         DoB         DoB       23.0           1.0
# 317           AgeGenderSheet         DoB         DoB       23.0           1.0
# ...                      ...         ...         ...        ...           ...
# 1146  MaritalDepartmentSheet  Department        Name        2.0           5.0
# 1163  MaritalDepartmentSheet  Department  Department        2.0           5.0
# 1167  MaritalDepartmentSheet  Department  Department        2.0           5.0
# 1171  MaritalDepartmentSheet  Department  Department        2.0           5.0
# 1175  MaritalDepartmentSheet  Department  Department        2.0           5.0
#
#       EndRow RowFromReferenceText ColumnFromReferenceText FieldPosition  \
# 148      NaN                    2                       0             1
# 154      NaN                    2                       0             1
# 160      NaN                    2                       0             1
# 311      NaN                    2                       1             2
# 317      NaN                    2                       1             2
# ...      ...                  ...                     ...           ...
# 1146     NaN                    2                       0             1
# 1163     NaN                    2                       1             2
# 1167     NaN                    2                       1             2
# 1171     NaN                    2                       1             2
# 1175     NaN                    2                       1             2
#
#      StartRow FieldColumn
# 148        25           1
# 154        25           1
# 160        25           1
# 311        25           2
# 317        25           2
# ...       ...         ...
# 1146        4           5
# 1163        4           6
# 1167        4           6
# 1171        4           6
# 1175        4           6
#
# [63 rows x 16 columns]

# %% [markdown]
# # Create a CellValue as Number for use in Formulae

# %%
dataset = dataset[['DataSetID', 'SheetName', 'FieldID', 'RowID', 'ColumnID','CellValue', 'CellType']].copy()
dataset['DataSetID']
# Out:
# 148            DoB
# 154            DoB
# 160            DoB
# 311            DoB
# 317            DoB
#            ...
# 1146    Department
# 1163    Department
# 1167    Department
# 1171    Department
# 1175    Department
# Name: DataSetID, Length: 63, dtype: object

# %%
dataset['CellValueAsNumber'] = pd.to_numeric(dataset['CellValue'], errors='coerce')
dataset.head(5)
# Out:
#     DataSetID       SheetName FieldID  RowID  ColumnID            CellValue  \
# 148       DoB  AgeGenderSheet    Name     25         1                 Paul
# 154       DoB  AgeGenderSheet    Name     26         1                Ringo
# 160       DoB  AgeGenderSheet    Name     27         1                Brian
# 311       DoB  AgeGenderSheet     DoB     25         2  1955-07-01 00:00:00
# 317       DoB  AgeGenderSheet     DoB     26         2  1996-01-09 00:00:00
#
#     CellType  CellValueAsNumber
# 148     Text                NaN
# 154     Text                NaN
# 160     Text                NaN
# 311     Date                NaN
# 317     Date                NaN

# %% [markdown]
# # Create a List of Checks to do

# %%
todolist = pd.DataFrame()
todolist = pd.merge(dataset, Tests2DoWithFormula, on=['DataSetID', 'FieldID'])
todolist.head(5)
# Out:
#   DataSetID     SheetName_x FieldID  RowID  ColumnID            CellValue  \
# 0       DoB  AgeGenderSheet    Name     25         1                 Paul
# 1       DoB  AgeGenderSheet    Name     26         1                Ringo
# 2       DoB  AgeGenderSheet    Name     27         1                Brian
# 3       DoB  AgeGenderSheet     DoB     25         2  1955-07-01 00:00:00
# 4       DoB  AgeGenderSheet     DoB     26         2  1996-01-09 00:00:00
#
#   CellType  CellValueAsNumber     SheetName_y ReferenceTextStart  ...  \
# 0     Text                NaN  AgeGenderSheet          DOB Table  ...
# 1     Text                NaN  AgeGenderSheet          DOB Table  ...
# 2     Text                NaN  AgeGenderSheet          DOB Table  ...
# 3     Date                NaN  AgeGenderSheet          DOB Table  ...
# 4     Date                NaN  AgeGenderSheet          DOB Table  ...
#
#   FormulaKeyWord List          Rule     CheckPerformed      ErrorMessage  \
# 0            NaN  NaN  Must Be Text  Data Type is Text  Text Not Entered
# 1            NaN  NaN  Must Be Text  Data Type is Text  Text Not Entered
# 2            NaN  NaN  Must Be Text  Data Type is Text  Text Not Entered
# 3            NaN  NaN  Must Be Date  Data Type is Date  Date Not Entered
# 4            NaN  NaN  Must Be Date  Data Type is Date  Date Not Entered
#
#   AlteryxDataType                                     AlteryxFormula  \
# 0        V_String  Length([CellValue]) > 0 and Contains([CellType...
# 1        V_String  Length([CellValue]) > 0 and Contains([CellType...
# 2        V_String  Length([CellValue]) > 0 and Contains([CellType...
# 3            Date    Length([CellValue]) > 0 and [CellType] = "Date"
# 4            Date    Length([CellValue]) > 0 and [CellType] = "Date"
#
#   RemedialAction                                         SQLFormula  \
# 0  Enter as Text  case when IsNULL([CellValue],'XX') = 'XX' then...
# 1  Enter as Text  case when IsNULL([CellValue],'XX') = 'XX' then...
# 2  Enter as Text  case when IsNULL([CellValue],'XX') = 'XX' then...
# 3     Enter Date  case when IsNULL([CellValue],'XX') = 'XX' then...
# 4     Enter Date  case when IsNULL([CellValue],'XX') = 'XX' then...
#
#                                    PythonFormula
# 0  np.where(dataset['CellType'] == 'Text', 1, 0)
# 1  np.where(dataset['CellType'] == 'Text', 1, 0)
# 2  np.where(dataset['CellType'] == 'Text', 1, 0)
# 3  np.where(dataset['CellType'] == 'Date', 1, 0)
# 4  np.where(dataset['CellType'] == 'Date', 1, 0)
#
# [5 rows x 29 columns]

# %% [markdown]
# # Create a List of distinct formula to apply

# %%
formulas = pd.DataFrame()
formulas = pd.DataFrame(todolist, columns=['KeyWord','PythonFormula'])
formulas = formulas.drop_duplicates()
formulas.head(10)
# Out:
#            KeyWord                                      PythonFormula
# 0             Text      np.where(dataset['CellType'] == 'Text', 1, 0)
# 3             Date      np.where(dataset['CellType'] == 'Date', 1, 0)
# 13          Number    np.where(dataset['CellType'] == 'Number', 1, 0)
# 14        Positive   np.where(dataset['CellValueAsNumber'] > 0, 1, 0)
# 15  GreaterThanTen  np.where(dataset['CellValueAsNumber'] > 10, 1, 0)
# 42        PickList                                                NaN

# %% [markdown]
# # Prepare Results Table

# %%
global bigresults
littletodolist = pd.DataFrame()
littletodolistworking = pd.DataFrame()
bigresults = pd.DataFrame()

# %%
# this was an important test as if you do not have copy you get an error as it believes
# you are trying to change a view
#littletodolist = todolist[(todolist.KeyWord == 'PickList')].copy()
#littletodolist.head(100)
#filterdf = pd.DataFrame()
#filterdf = todolist[(todolist.KeyWord == 'PickList')].copy()
#filterdf.head()

# %%
# littletodolist.loc[littletodolist.KeyWord == 'Text', 'Result'] = np.where(littletodolist['CellType'] == 'Text', 1, 0)

# %% [markdown]
# # Loop through each Formula and apply to the To Do List

# %%
todolist = todolist.rename(columns={'CellValue_x': 'CellValue'})
##todolist.columns

# %%
for index, row in formulas.iterrows():
  # print(row['KeyWord'],row['PythonFormula'])

  pf = row['PythonFormula']
  kw = row['KeyWord']
 
  try:
      pf1 = pf.replace("dataset", "littletodolist")
  except:
      pf1 = "1"
  littletodolist = todolist[(todolist.KeyWord == kw)].copy()
  formula2do = "littletodolist['Result'] = " + pf1
  print(kw)
  print(formula2do)
  exec(formula2do)
  ##print(littletodolist)
  ##try:
  ##bigresults = pd.concat([bigresults, littletodolist], ignore_index=True).drop_duplicates().reset_index(drop=True)
  bigresults = pd.concat([bigresults, littletodolist]) ##, ignore_index=True).drop_duplicates().reset_index(drop=True)
  ##except:
  #  bigresults = bigresults
# Out:
# Text
# littletodolist['Result'] = np.where(littletodolist['CellType'] == 'Text', 1, 0)
# Date
# littletodolist['Result'] = np.where(littletodolist['CellType'] == 'Date', 1, 0)
# Number
# littletodolist['Result'] = np.where(littletodolist['CellType'] == 'Number', 1, 0)
# Positive
# littletodolist['Result'] = np.where(littletodolist['CellValueAsNumber'] > 0, 1, 0)
# GreaterThanTen
# littletodolist['Result'] = np.where(littletodolist['CellValueAsNumber'] > 10, 1, 0)
# PickList
# littletodolist['Result'] = 1

# %%
littletodolist['Result'] = np.where(littletodolist['CellType'] == 'Text', 1, 0)

# %% [markdown]
# # Add a sequence to the Results for use in Reporting

# %%
bigresults['ResultID'] = bigresults.index

# %%
bigresults.head(5)
# Out:
#   DataSetID     SheetName_x FieldID  RowID  ColumnID CellValue CellType  \
# 0       DoB  AgeGenderSheet    Name     25         1      Paul     Text
# 1       DoB  AgeGenderSheet    Name     26         1     Ringo     Text
# 2       DoB  AgeGenderSheet    Name     27         1     Brian     Text
# 6      Ages  AgeGenderSheet    Name      7         3      Paul     Text
# 7      Ages  AgeGenderSheet    Name      8         3     Ringo     Text
#
#    CellValueAsNumber     SheetName_y ReferenceTextStart  ...          Rule  \
# 0                NaN  AgeGenderSheet          DOB Table  ...  Must Be Text
# 1                NaN  AgeGenderSheet          DOB Table  ...  Must Be Text
# 2                NaN  AgeGenderSheet          DOB Table  ...  Must Be Text
# 6                NaN  AgeGenderSheet          Age Table  ...  Must Be Text
# 7                NaN  AgeGenderSheet          Age Table  ...  Must Be Text
#
#       CheckPerformed      ErrorMessage AlteryxDataType  \
# 0  Data Type is Text  Text Not Entered        V_String
# 1  Data Type is Text  Text Not Entered        V_String
# 2  Data Type is Text  Text Not Entered        V_String
# 6  Data Type is Text  Text Not Entered        V_String
# 7  Data Type is Text  Text Not Entered        V_String
#
#                                       AlteryxFormula RemedialAction  \
# 0  Length([CellValue]) > 0 and Contains([CellType...  Enter as Text
# 1  Length([CellValue]) > 0 and Contains([CellType...  Enter as Text
# 2  Length([CellValue]) > 0 and Contains([CellType...  Enter as Text
# 6  Length([CellValue]) > 0 and Contains([CellType...  Enter as Text
# 7  Length([CellValue]) > 0 and Contains([CellType...  Enter as Text
#
#                                           SQLFormula  \
# 0  case when IsNULL([CellValue],'XX') = 'XX' then...
# 1  case when IsNULL([CellValue],'XX') = 'XX' then...
# 2  case when IsNULL([CellValue],'XX') = 'XX' then...
# 6  case when IsNULL([CellValue],'XX') = 'XX' then...
# 7  case when IsNULL([CellValue],'XX') = 'XX' then...
#
#                                    PythonFormula Result ResultID
# 0  np.where(dataset['CellType'] == 'Text', 1, 0)      1        0
# 1  np.where(dataset['CellType'] == 'Text', 1, 0)      1        1
# 2  np.where(dataset['CellType'] == 'Text', 1, 0)      1        2
# 6  np.where(dataset['CellType'] == 'Text', 1, 0)      1        6
# 7  np.where(dataset['CellType'] == 'Text', 1, 0)      1        7
#
# [5 rows x 31 columns]

# %% [markdown]
# # Narrow down Results to useful columnns

# %%
usefulresults = pd.DataFrame()
usefulresults = pd.DataFrame(bigresults, columns=['DataSetID','FieldID','RowID','ColumnID','CellValue','CellType','CheckPerformed', 'Result'])
usefulresults.head()
# Out:
#   DataSetID FieldID  RowID  ColumnID CellValue CellType     CheckPerformed  \
# 0       DoB    Name     25         1      Paul     Text  Data Type is Text
# 1       DoB    Name     26         1     Ringo     Text  Data Type is Text
# 2       DoB    Name     27         1     Brian     Text  Data Type is Text
# 6      Ages    Name      7         3      Paul     Text  Data Type is Text
# 7      Ages    Name      8         3     Ringo     Text  Data Type is Text
#
#    Result
# 0       1
# 1       1
# 2       1
# 6       1
# 7       1

# %% [markdown]
# # Summarise Results

# %%
resultssummary = pd.DataFrame()
# index = pd.MultiIndex.from_arrays(arrays, names=['first', 'second'])
# resultssummary.head()

resultssummary = bigresults[['DataSetID','FieldID','CheckPerformed', 'Result', 'ResultID']].groupby(['DataSetID', 'FieldID', 'CheckPerformed']).agg(['count'])
resultssummary.head(5)
# Out:
#                                       Result ResultID
#                                        count    count
# DataSetID FieldID CheckPerformed
# Ages      Age     Data Type is Number      7        7
#                   Greater than 10          7        7
#                   Number is Positive       7        7
#           Name    Data Type is Text        7        7
# DoB       DoB     Data Type is Date        3        3

# %% [markdown]
# # Pivot Results

# %%
# rownamearray = pd.array(['DataSet','FieldID'], dtype=str)
# newct = pd.crosstab(bigresults.DataSet,bigresults.FieldID,bigresults.CheckPerformed,bigresults.Result,rownames=rownamearray, colnames=['Result'])

newct = bigresults.pivot_table(index = ['DataSetID','FieldID','CheckPerformed'], values = 'ResultID',columns = 'Result', aggfunc = 'count')
newct
# Out:
# Result                                              0    1
# DataSetID     FieldID       CheckPerformed
# Ages          Age           Data Type is Number   5.0  2.0
#                             Greater than 10       5.0  2.0
#                             Number is Positive    5.0  2.0
#               Name          Data Type is Text     NaN  7.0
# DoB           DoB           Data Type is Date     1.0  2.0
#               Name          Data Type is Text     NaN  3.0
# Genders       Gender        Data Type is Text     NaN  7.0
#                             Validate to Picklist  NaN  7.0
#               Name          Data Type is Text     NaN  7.0
# HomeLocation  Employee      Data Type is Text     NaN  3.0
#               Location      Data Type is Text     NaN  3.0
#                             Validate to Picklist  NaN  3.0
# Jobs          Employee_Name Data Type is Text     NaN  3.0
#               ID            Data Type is Number   1.0  2.0
#               Job_Title     Data Type is Text     NaN  3.0
# MaritalStatus Name          Data Type is Text     NaN  3.0
#               Status        Data Type is Text     NaN  3.0
#                             Validate to Picklist  NaN  3.0

# %% [markdown]
# # Plot Stack Bar

# %% [markdown]
# ## Show Stack

# %%
newct.plot(kind='barh', stacked=True)
# Out:
# <Axes: ylabel='DataSetID,FieldID,CheckPerformed'>
